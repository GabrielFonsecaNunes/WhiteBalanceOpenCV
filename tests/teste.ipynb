# %%
import pandas as pd

df = pd.read_csv("../data/conversion_rgb_temp.csv", sep=";")
# Out:
#     Unnamed: 0                                    Temperature [K]  \
# 0            0  1000 K   2deg  0.6499 0.3474  2.472e+06    1.0...
# 1            1  1600 K   2deg  0.5720 0.4025  1.967e+10    1.0...
# 2            2  2200 K   2deg  0.5062 0.4196  1.322e+12    1.0...
# 3            3  2800 K   2deg  0.4535 0.4139  1.524e+13    1.0...
# 4            4  3400 K   2deg  0.4132 0.3990  7.545e+13    1.0...
# ..         ...                                                ...
# 60          60  37000 K   2deg  0.2494 0.2449  1.537e+17    0....
# 61          61  37600 K   2deg  0.2493 0.2446  1.572e+17    0....
# 62          62  38200 K   2deg  0.2491 0.2444  1.607e+17    0....
# 63          63  38800 K   2deg  0.2490 0.2442  1.642e+17    0....
# 64          64  39400 K   2deg  0.2489 0.2440  1.677e+17    0....
#
#                                                   CMF  \
# 0   1000 K  10deg  0.6472 0.3506  2.525e+06    1.0...
# 1   1600 K  10deg  0.5747 0.3996  2.028e+10    1.0...
# ...
